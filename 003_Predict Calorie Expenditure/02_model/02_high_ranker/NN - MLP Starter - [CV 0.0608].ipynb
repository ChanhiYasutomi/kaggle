# %% [markdown]
# # NN Starter - CV 0.0608 - Wow!
# Hi everyone. Here is a simple NN MLP starter for Kaggle's May playground competition predicting Calorie expenditure. Using simple architecture and no feature engineering it achieves CV score 0.0608 wow!

# %% [markdown]
# # Load Data
# We load train, test, and original datasets.

# %%
import pandas as pd, numpy as np
VER=1

# LOAD DATA
train = pd.read_csv("/kaggle/input/playground-series-s5e5/train.csv")
test = pd.read_csv("/kaggle/input/playground-series-s5e5/test.csv")
orig = pd.read_csv("/kaggle/input/calories-burnt-prediction/calories.csv")
orig = orig.rename({"Gender":"Sex"},axis=1)
orig = orig.rename({"User_ID":"id"},axis=1)
orig['id'] = np.arange( len(orig) ) + 1_000_000

# DISPLAY DATA
print("Train shape, test shape, original shape:")
print(train.shape, test.shape, orig.shape)
train.head()
# Out:
# Train shape, test shape, original shape:
# (750000, 9) (250000, 8) (15000, 9)
#    id     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0   0    male   36   189.0    82.0      26.0       101.0       41.0     150.0
# 1   1  female   64   163.0    60.0       8.0        85.0       39.7      34.0
# 2   2  female   51   161.0    64.0       7.0        84.0       39.8      29.0
# 3   3    male   20   192.0    90.0      25.0       105.0       40.7     140.0
# 4   4  female   38   166.0    61.0      25.0       102.0       40.6     146.0

# %% [markdown]
# # Feature Engineer
# We use no feature engineering besides label encoding column Sex.

# %%
for df in [train,test, orig]:
    df['Sex'] = df['Sex'].map({'male':0,'female':1}).astype('float32')

# %%
FEATURES = ['Sex', 'Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp']
TARGET = 'Calories'

# %% [markdown]
# # Build NN Model
# We build a simple TensorFlow MLP with 3 hidden layers, batch normalization, and activation Swish.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Embedding
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.layers import Activation
import tensorflow.keras.backend as K

print('TF Version',tf.__version__)
# Out:
# 2025-05-05 20:14:49.296685: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746476089.803586      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746476089.926332      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# TF Version 2.18.0

# %%
# SIMPLE MLP
def build_model(size=len(FEATURES)):
    x_in = Input(shape=(size,))
    x = Dense(32)(x_in)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)

    x = Dense(64)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)

    x = Dense(32)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)

    x = Dense(1, activation='linear')(x)
    model = Model(inputs=x_in, outputs=x)
    return model

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping

def make_callbacks():
    lr_callback = ReduceLROnPlateau(
        monitor='val_loss',     
        factor=0.5,              
        patience=3,              
        verbose=1,               
        min_lr=1e-6              
    )
    early_stop_cb = EarlyStopping(
        monitor="val_loss", 
        patience=10,            
        restore_best_weights=True,
        mode="min", 
        verbose=1
    )
    return [lr_callback, early_stop_cb]

EPOCHS = 100

# %% [markdown]
# # Train NN Model
# We train 5 KFold with early stopping and reduce on plateau learning rate. We train on `log1p` transformed target using RMSE loss. This optimizes the competition metric of RMSLE.

# %%
import time
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

FOLDS = 5
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)

oof = np.zeros(len(train))
pred = np.zeros(len(test))

for i, (train_idx, valid_idx) in enumerate(kf.split(train)):
    
    print(f"\n{'#'*28}")
    print(f"{'#'*10} Fold {i+1} {'#'*10}")
    print(f"{'#'*28}")

    # TRAIN
    X_train = train.loc[train_idx,FEATURES].copy()
    y_train = np.log1p( train.loc[train_idx,TARGET] )

    # EXTRA DATA
    for k in range(4):
        X_train = pd.concat([X_train,orig[FEATURES]],axis=0)
        y_train = pd.concat([y_train,np.log1p( orig[TARGET] )],axis=0)

    # VALID
    X_valid = train.loc[valid_idx,FEATURES].copy()
    y_valid = np.log1p( train.loc[valid_idx,TARGET] )

    # TEST
    X_test = test[FEATURES].copy()

    # NORMALIZE FOR NN
    print("Normalizing...", end='')
    norm_cols = [c for c in FEATURES if c not in []]
    means = X_train[norm_cols].mean()
    stds = X_train[norm_cols].std()
    stds = stds.replace(0, 1)
    X_train[norm_cols] = (X_train[norm_cols] - means) / stds
    X_valid[norm_cols] = (X_valid[norm_cols] - means) / stds
    X_test[norm_cols] = (X_test[norm_cols] - means) / stds
    print("done")
    
    start = time.time()

    K.clear_session()
    model = build_model( X_train.shape[1] )
    model.compile(optimizer=tf.keras.optimizers.Adam(0.001), 
                    loss="mse", 
                    metrics=[tf.keras.metrics.RootMeanSquaredError()],
                 )
    model.fit(X_train, y_train, 
              validation_data = (X_valid, y_valid),
              callbacks = make_callbacks(),
              batch_size=256, epochs=EPOCHS, verbose=2)

    oof[valid_idx] = model.predict(X_valid,batch_size=512,verbose=2).flatten()
    pred += model.predict(X_test,batch_size=512,verbose=2).flatten()

    rmse = np.sqrt(mean_squared_error(y_valid, oof[valid_idx]))
    print(f"Fold {i+1} RMSE: {rmse:.4f}")
    print(f"Feature engineering & training time: {time.time() - start:.1f} sec")

pred /= FOLDS
# Out:
# ############################
# ########## Fold 1 ##########
# ############################
# Normalizing...done
# I0000 00:00:1746476112.208820      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1746476112.209460      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746476117.083820      64 service.cc:148] XLA service 0x7c0abc023ba0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746476117.084947      64 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746476117.084965      64 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746476117.501097      64 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1746476119.104586      64 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2579/2579 - 11s - 4ms/step - loss: 0.4503 - root_mean_squared_error: 0.6710 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0929 - learning_rate: 0.0010
# Epoch 2/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0742 - learning_rate: 0.0010
# Epoch 3/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0090 - root_mean_squared_error: 0.0947 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0957 - learning_rate: 0.0010
# Epoch 4/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829 - learning_rate: 0.0010
# Epoch 5/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.0880 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0674 - learning_rate: 0.0010
# Epoch 6/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0071 - root_mean_squared_error: 0.0844 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0834 - learning_rate: 0.0010
# Epoch 7/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0068 - root_mean_squared_error: 0.0822 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0706 - learning_rate: 0.0010
# Epoch 8/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0643 - learning_rate: 0.0010
# Epoch 9/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0061 - root_mean_squared_error: 0.0781 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0838 - learning_rate: 0.0010
# Epoch 10/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0057 - root_mean_squared_error: 0.0757 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0721 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2579/2579 - 4s - 2ms/step - loss: 0.0056 - root_mean_squared_error: 0.0748 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0779 - learning_rate: 0.0010
# Epoch 12/100
# 2579/2579 - 5s - 2ms/step - loss: 0.0049 - root_mean_squared_error: 0.0699 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0662 - learning_rate: 5.0000e-04
# Epoch 13/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0049 - root_mean_squared_error: 0.0697 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0676 - learning_rate: 5.0000e-04
# Epoch 14/100
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2579/2579 - 4s - 2ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0650 - learning_rate: 5.0000e-04
# Epoch 15/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0615 - learning_rate: 2.5000e-04
# Epoch 16/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0666 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0624 - learning_rate: 2.5000e-04
# Epoch 17/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0670 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 2.5000e-04
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0668 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0628 - learning_rate: 2.5000e-04
# Epoch 19/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0655 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0624 - learning_rate: 1.2500e-04
# Epoch 20/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619 - learning_rate: 1.2500e-04
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0656 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0612 - learning_rate: 1.2500e-04
# Epoch 22/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0651 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 6.2500e-05
# Epoch 23/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0649 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608 - learning_rate: 6.2500e-05
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0650 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 6.2500e-05
# Epoch 25/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608 - learning_rate: 3.1250e-05
# Epoch 26/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0646 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607 - learning_rate: 3.1250e-05
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609 - learning_rate: 3.1250e-05
# Epoch 28/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0644 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.5625e-05
# Epoch 29/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609 - learning_rate: 1.5625e-05
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.5625e-05
# Epoch 31/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0041 - root_mean_squared_error: 0.0642 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608 - learning_rate: 7.8125e-06
# Epoch 32/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0041 - root_mean_squared_error: 0.0642 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 7.8125e-06
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0041 - root_mean_squared_error: 0.0642 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 7.8125e-06
# Epoch 34/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0041 - root_mean_squared_error: 0.0642 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608 - learning_rate: 3.9063e-06
# Epoch 35/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0041 - root_mean_squared_error: 0.0643 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608 - learning_rate: 3.9063e-06
# Epoch 36/100
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0041 - root_mean_squared_error: 0.0640 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608 - learning_rate: 3.9063e-06
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 293/293 - 1s - 5ms/step
# 489/489 - 1s - 2ms/step
# Fold 1 RMSE: 0.0607
# Feature engineering & training time: 169.4 sec
#
# ############################
# ########## Fold 2 ##########
# ############################
# Normalizing...done
# Epoch 1/100
# 2579/2579 - 10s - 4ms/step - loss: 0.7923 - root_mean_squared_error: 0.8901 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0832 - learning_rate: 0.0010
# Epoch 2/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992 - learning_rate: 0.0010
# Epoch 3/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0708 - learning_rate: 0.0010
# Epoch 4/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0084 - root_mean_squared_error: 0.0919 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0753 - learning_rate: 0.0010
# Epoch 5/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0766 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2579/2579 - 4s - 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.0854 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0727 - learning_rate: 0.0010
# Epoch 7/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0063 - root_mean_squared_error: 0.0795 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653 - learning_rate: 5.0000e-04
# Epoch 8/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0650 - learning_rate: 5.0000e-04
# Epoch 9/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0057 - root_mean_squared_error: 0.0756 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0666 - learning_rate: 5.0000e-04
# Epoch 10/100
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2579/2579 - 4s - 2ms/step - loss: 0.0056 - root_mean_squared_error: 0.0750 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0651 - learning_rate: 5.0000e-04
# Epoch 11/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0637 - learning_rate: 2.5000e-04
# Epoch 12/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658 - learning_rate: 2.5000e-04
# Epoch 13/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0050 - root_mean_squared_error: 0.0709 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0626 - learning_rate: 2.5000e-04
# Epoch 14/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0049 - root_mean_squared_error: 0.0703 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0628 - learning_rate: 2.5000e-04
# Epoch 15/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634 - learning_rate: 2.5000e-04
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2579/2579 - 4s - 2ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0623 - learning_rate: 2.5000e-04
# Epoch 17/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0046 - root_mean_squared_error: 0.0678 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0631 - learning_rate: 1.2500e-04
# Epoch 18/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0623 - learning_rate: 1.2500e-04
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619 - learning_rate: 1.2500e-04
# Epoch 20/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0664 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0622 - learning_rate: 6.2500e-05
# Epoch 21/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0667 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0620 - learning_rate: 6.2500e-05
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0622 - learning_rate: 6.2500e-05
# Epoch 23/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0617 - learning_rate: 3.1250e-05
# Epoch 24/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619 - learning_rate: 3.1250e-05
# Epoch 25/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 3.1250e-05
# Epoch 26/100
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 3.1250e-05
# Epoch 27/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 1.5625e-05
# Epoch 28/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0654 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0617 - learning_rate: 1.5625e-05
# Epoch 29/100
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0617 - learning_rate: 1.5625e-05
# Epoch 30/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0652 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 7.8125e-06
# Epoch 31/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0656 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 7.8125e-06
# Epoch 32/100
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0651 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0617 - learning_rate: 7.8125e-06
# Epoch 33/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0655 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 3.9063e-06
# Epoch 34/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0652 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 3.9063e-06
# Epoch 35/100
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0654 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 3.9063e-06
# Epoch 36/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 1.9531e-06
# Epoch 37/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0656 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 1.9531e-06
# Epoch 38/100
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0651 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 1.9531e-06
# Epoch 39/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 1.0000e-06
# Epoch 40/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0654 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 1.0000e-06
# Epoch 41/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0652 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 1.0000e-06
# Epoch 42/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0650 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 1.0000e-06
# Epoch 43/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616 - learning_rate: 1.0000e-06
# Epoch 44/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0655 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 1.0000e-06
# Epoch 45/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0655 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 1.0000e-06
# Epoch 46/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0655 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 1.0000e-06
# Epoch 47/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 1.0000e-06
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 37.
# 293/293 - 1s - 3ms/step
# 489/489 - 1s - 1ms/step
# Fold 2 RMSE: 0.0613
# Feature engineering & training time: 209.3 sec
#
# ############################
# ########## Fold 3 ##########
# ############################
# Normalizing...done
# Epoch 1/100
# 2579/2579 - 9s - 4ms/step - loss: 0.6998 - root_mean_squared_error: 0.8365 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0884 - learning_rate: 0.0010
# Epoch 2/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0786 - learning_rate: 0.0010
# Epoch 3/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1039 - learning_rate: 0.0010
# Epoch 4/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0093 - root_mean_squared_error: 0.0963 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701 - learning_rate: 0.0010
# Epoch 5/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0086 - root_mean_squared_error: 0.0929 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0728 - learning_rate: 0.0010
# Epoch 6/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0082 - root_mean_squared_error: 0.0904 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0921 - learning_rate: 0.0010
# Epoch 7/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0076 - root_mean_squared_error: 0.0870 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648 - learning_rate: 0.0010
# Epoch 8/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0071 - root_mean_squared_error: 0.0841 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0663 - learning_rate: 0.0010
# Epoch 9/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0066 - root_mean_squared_error: 0.0814 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0632 - learning_rate: 0.0010
# Epoch 10/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0063 - root_mean_squared_error: 0.0794 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0732 - learning_rate: 0.0010
# Epoch 11/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0061 - root_mean_squared_error: 0.0784 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0727 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2579/2579 - 4s - 2ms/step - loss: 0.0058 - root_mean_squared_error: 0.0763 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0678 - learning_rate: 0.0010
# Epoch 13/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0051 - root_mean_squared_error: 0.0717 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655 - learning_rate: 5.0000e-04
# Epoch 14/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0631 - learning_rate: 5.0000e-04
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2579/2579 - 4s - 2ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0635 - learning_rate: 5.0000e-04
# Epoch 16/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0047 - root_mean_squared_error: 0.0686 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0640 - learning_rate: 2.5000e-04
# Epoch 17/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0047 - root_mean_squared_error: 0.0682 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641 - learning_rate: 2.5000e-04
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2579/2579 - 4s - 2ms/step - loss: 0.0047 - root_mean_squared_error: 0.0682 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664 - learning_rate: 2.5000e-04
# Epoch 19/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0671 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616 - learning_rate: 1.2500e-04
# Epoch 20/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0667 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0612 - learning_rate: 1.2500e-04
# Epoch 21/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0664 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619 - learning_rate: 1.2500e-04
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0664 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.2500e-04
# Epoch 23/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0655 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 6.2500e-05
# Epoch 24/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 6.2500e-05
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 6.2500e-05
# Epoch 26/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609 - learning_rate: 3.1250e-05
# Epoch 27/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0655 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 3.1250e-05
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0650 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 3.1250e-05
# Epoch 29/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0650 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.5625e-05
# Epoch 30/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0654 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0612 - learning_rate: 1.5625e-05
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0652 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.5625e-05
# Epoch 32/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0649 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 7.8125e-06
# Epoch 33/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0652 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 7.8125e-06
# Epoch 34/100
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0651 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 7.8125e-06
# Epoch 35/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0652 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 3.9063e-06
# Epoch 36/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0649 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609 - learning_rate: 3.9063e-06
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 293/293 - 1s - 3ms/step
# 489/489 - 1s - 1ms/step
# Fold 3 RMSE: 0.0609
# Feature engineering & training time: 161.9 sec
#
# ############################
# ########## Fold 4 ##########
# ############################
# Normalizing...done
# Epoch 1/100
# 2579/2579 - 9s - 4ms/step - loss: 0.7142 - root_mean_squared_error: 0.8451 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016 - learning_rate: 0.0010
# Epoch 2/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0110 - root_mean_squared_error: 0.1048 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0745 - learning_rate: 0.0010
# Epoch 3/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0920 - learning_rate: 0.0010
# Epoch 4/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0089 - root_mean_squared_error: 0.0941 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0656 - learning_rate: 0.0010
# Epoch 5/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0083 - root_mean_squared_error: 0.0910 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0772 - learning_rate: 0.0010
# Epoch 6/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.0880 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0729 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2579/2579 - 4s - 2ms/step - loss: 0.0071 - root_mean_squared_error: 0.0842 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0748 - learning_rate: 0.0010
# Epoch 8/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0060 - root_mean_squared_error: 0.0776 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0622 - learning_rate: 5.0000e-04
# Epoch 9/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0058 - root_mean_squared_error: 0.0763 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0626 - learning_rate: 5.0000e-04
# Epoch 10/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0056 - root_mean_squared_error: 0.0750 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658 - learning_rate: 5.0000e-04
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2579/2579 - 4s - 2ms/step - loss: 0.0055 - root_mean_squared_error: 0.0740 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0652 - learning_rate: 5.0000e-04
# Epoch 12/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0050 - root_mean_squared_error: 0.0710 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0639 - learning_rate: 2.5000e-04
# Epoch 13/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616 - learning_rate: 2.5000e-04
# Epoch 14/100
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2579/2579 - 4s - 2ms/step - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0642 - learning_rate: 2.5000e-04
# Epoch 15/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0047 - root_mean_squared_error: 0.0684 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0627 - learning_rate: 1.2500e-04
# Epoch 16/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0047 - root_mean_squared_error: 0.0682 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0639 - learning_rate: 1.2500e-04
# Epoch 17/100
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0046 - root_mean_squared_error: 0.0678 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0621 - learning_rate: 1.2500e-04
# Epoch 18/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0670 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 6.2500e-05
# Epoch 19/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0668 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614 - learning_rate: 6.2500e-05
# Epoch 20/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0615 - learning_rate: 6.2500e-05
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0670 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0612 - learning_rate: 6.2500e-05
# Epoch 22/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0664 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0612 - learning_rate: 3.1250e-05
# Epoch 23/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0666 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 3.1250e-05
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 3.1250e-05
# Epoch 25/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.5625e-05
# Epoch 26/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.5625e-05
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0612 - learning_rate: 1.5625e-05
# Epoch 28/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 7.8125e-06
# Epoch 29/100
# 2579/2579 - 5s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 7.8125e-06
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 7.8125e-06
# Epoch 31/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 3.9063e-06
# Epoch 32/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 3.9063e-06
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 3.9063e-06
# Epoch 34/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.9531e-06
# Epoch 35/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.9531e-06
# Epoch 36/100
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.9531e-06
# Epoch 37/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.0000e-06
# Epoch 38/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0656 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.0000e-06
# Epoch 39/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.0000e-06
# Epoch 40/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.0000e-06
# Epoch 41/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.0000e-06
# Epoch 42/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.0000e-06
# Epoch 43/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.0000e-06
# Epoch 44/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.0000e-06
# Epoch 45/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.0000e-06
# Epoch 46/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.0000e-06
# Epoch 47/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.0000e-06
# Epoch 48/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.0000e-06
# Epoch 49/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.0000e-06
# Epoch 50/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.0000e-06
# Epoch 51/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 1.0000e-06
# Epoch 52/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.0000e-06
# Epoch 53/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611 - learning_rate: 1.0000e-06
# Epoch 54/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.0000e-06
# Epoch 55/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 1.0000e-06
# Epoch 55: early stopping
# Restoring model weights from the end of the best epoch: 45.
# 293/293 - 1s - 3ms/step
# 489/489 - 1s - 1ms/step
# Fold 4 RMSE: 0.0610
# Feature engineering & training time: 245.0 sec
#
# ############################
# ########## Fold 5 ##########
# ############################
# Normalizing...done
# Epoch 1/100
# 2579/2579 - 9s - 4ms/step - loss: 0.7049 - root_mean_squared_error: 0.8396 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1017 - learning_rate: 0.0010
# Epoch 2/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0105 - root_mean_squared_error: 0.1023 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0713 - learning_rate: 0.0010
# Epoch 3/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0091 - root_mean_squared_error: 0.0956 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0683 - learning_rate: 0.0010
# Epoch 4/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0086 - root_mean_squared_error: 0.0928 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801 - learning_rate: 0.0010
# Epoch 5/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0082 - root_mean_squared_error: 0.0903 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2579/2579 - 4s - 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.0861 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710 - learning_rate: 0.0010
# Epoch 7/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0064 - root_mean_squared_error: 0.0802 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0757 - learning_rate: 5.0000e-04
# Epoch 8/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0062 - root_mean_squared_error: 0.0786 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0747 - learning_rate: 5.0000e-04
# Epoch 9/100
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2579/2579 - 4s - 2ms/step - loss: 0.0059 - root_mean_squared_error: 0.0770 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0713 - learning_rate: 5.0000e-04
# Epoch 10/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0642 - learning_rate: 2.5000e-04
# Epoch 11/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0052 - root_mean_squared_error: 0.0722 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634 - learning_rate: 2.5000e-04
# Epoch 12/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0052 - root_mean_squared_error: 0.0718 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0636 - learning_rate: 2.5000e-04
# Epoch 13/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0051 - root_mean_squared_error: 0.0711 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0612 - learning_rate: 2.5000e-04
# Epoch 14/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0624 - learning_rate: 2.5000e-04
# Epoch 15/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0643 - learning_rate: 2.5000e-04
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2579/2579 - 4s - 2ms/step - loss: 0.0049 - root_mean_squared_error: 0.0697 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679 - learning_rate: 2.5000e-04
# Epoch 17/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0047 - root_mean_squared_error: 0.0684 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613 - learning_rate: 1.2500e-04
# Epoch 18/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0047 - root_mean_squared_error: 0.0683 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0612 - learning_rate: 1.2500e-04
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0046 - root_mean_squared_error: 0.0681 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0620 - learning_rate: 1.2500e-04
# Epoch 20/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0670 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0618 - learning_rate: 6.2500e-05
# Epoch 21/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0046 - root_mean_squared_error: 0.0675 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619 - learning_rate: 6.2500e-05
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0669 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608 - learning_rate: 6.2500e-05
# Epoch 23/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0045 - root_mean_squared_error: 0.0667 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608 - learning_rate: 3.1250e-05
# Epoch 24/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0666 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608 - learning_rate: 3.1250e-05
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609 - learning_rate: 3.1250e-05
# Epoch 26/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607 - learning_rate: 1.5625e-05
# Epoch 27/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609 - learning_rate: 1.5625e-05
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606 - learning_rate: 1.5625e-05
# Epoch 29/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609 - learning_rate: 7.8125e-06
# Epoch 30/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610 - learning_rate: 7.8125e-06
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608 - learning_rate: 7.8125e-06
# Epoch 32/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609 - learning_rate: 3.9063e-06
# Epoch 33/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607 - learning_rate: 3.9063e-06
# Epoch 34/100
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606 - learning_rate: 3.9063e-06
# Epoch 35/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606 - learning_rate: 1.9531e-06
# Epoch 36/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606 - learning_rate: 1.9531e-06
# Epoch 37/100
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606 - learning_rate: 1.9531e-06
# Epoch 38/100
# 2579/2579 - 5s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607 - learning_rate: 1.0000e-06
# Epoch 39/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609 - learning_rate: 1.0000e-06
# Epoch 40/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606 - learning_rate: 1.0000e-06
# Epoch 41/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606 - learning_rate: 1.0000e-06
# Epoch 42/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606 - learning_rate: 1.0000e-06
# Epoch 43/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606 - learning_rate: 1.0000e-06
# Epoch 44/100
# 2579/2579 - 4s - 2ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606 - learning_rate: 1.0000e-06
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 34.
# 293/293 - 1s - 3ms/step
# 489/489 - 1s - 1ms/step
# Fold 5 RMSE: 0.0606
# Feature engineering & training time: 197.8 sec

# %% [markdown]
# # Compute CV Score
# Our simple MLP achieves CV score of 0.0608 wow!

# %%
full_rmse = np.sqrt(mean_squared_error(np.log1p(train[TARGET]), oof))
print(f"Overall CV RMSE: {full_rmse:.5f}")
np.save(f"oof_v{VER}",oof)
# Out:
# Overall CV RMSE: 0.06090

# %% [markdown]
# # Submission CSV

# %%
mn = train.Calories.min()
mx = train.Calories.max()
test['Calories'] = np.clip( np.expm1( pred ),mn,mx )
test[['id','Calories']].to_csv(f"submission_v{VER}.csv",index=False)
test[['id','Calories']].head()
# Out:
#        id    Calories
# 0  750000   27.493386
# 1  750001  107.591390
# 2  750002   86.302886
# 3  750003  124.900612
# 4  750004   75.880983

# %% [markdown]
# # EDA Test Preds

# %%
import matplotlib.pyplot as plt

plt.hist(test['Calories'],bins=100)
plt.title("Test Preds")
plt.show()
